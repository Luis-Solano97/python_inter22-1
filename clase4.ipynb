# %% [markdown]
# # FUNCIONES
# ![image.png](attachment:image.png)

# %%
#son bloques de codigo "independientes" 
#que se mandan a llamar cuando se necesiten

def sumar (a,b):
    resultado=a+b
    return resultado

# %%
print(sumar(8,10))
# Out:
# 18

# %%
# documentacion, esta aparece en la ayuda 
# de coolab y code, acepta markdown
def sumar (a,b):
    """ 
    funcion para sumar 2 numeros
    ## Parametros
    a, b : valores enteros
    ## Return
    la suma de a + b
    """
    resultado=a+b
    return resultado

# %%
sumar()

# %% [markdown]
# ## Actividad 1

# %%
def dolaresAPesos(dolares):
    """ 
    funcion que hace la concversion de dolares a pesos
    toma el valor de dolar a 19.76 pesos
    ## Parametros
    dolares: valor entero
    ## Return
    dolares multiplicado por 19.76
    """
    resultado=a*19.76
    return resultado

# %%
dolaresAPesos(20)
# Out:
# 395.20000000000005

# %% [markdown]
# ## Actividad 2

# %%
def promedio (lista):
    """ 
    funcion que saca el promedio de una lista
    ## Parametros
    lista: valores numericos
    ## Return
    promedio de los valores de la lista

    """
    resultado= sum(lista)/len(lista)
    return resultado

# %%
lista=[231,654,654.21,65]

promedio(lista)
# Out:
# 401.0525
